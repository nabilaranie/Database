# %% [markdown]
# <a href="https://colab.research.google.com/github/nabilaranie/Database/blob/main/Kelompok_F_KompStat_DataAggregation_CaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Aggregation and Group Operations
#
# ---
#
#
# ## Case Study / Exercise

# %% [markdown]
# * Kerjakan soal A dan B berikut secara berkelompok.
# * Yakinkan jupyter notebook (file .ipynb) yang dikumpulkan dapat di "run all" dengan sukses di Google Colab.
# * File ipynb ini dapat digunakan sebagai template jawaban.
# * Submit link Google Colab pada tempat pengumpulan di EMAS 2.

# %%
import pandas as pd

# %% [markdown]
# ## Soal A

# %% [markdown]
# Diberikan data dalam file CSV sebagai berikut, klik [di sini](https://media.geeksforgeeks.org/wp-content/uploads/nba.csv).
#
#
# 1.   Berapakah mean, min, dan max untuk kolom Age, Height, Weight, dan Salary? Aplikasikan fungsi aggregate untuk hal tersebut.
# 2.   Aplikasikan fungsi aggregate untuk menampilkan informasi max dan min dari kolom Number, max dan min dari kolom Age, min dan sum dari kolom Weight, serta max dan sum dari kolom Salary.
# 3. Ada berapa nama team yang berbeda dari data tersebut? Hitunglah banyak anggota dari masing-masing team.

# %%
#Untuk mengunduh data nba sehingga bisa diolah
# !wget https://raw.githubusercontent.com/ammarhan/First-Repo/main/nba.csv
# Out:
# --2023-12-04 08:03:40--  https://raw.githubusercontent.com/ammarhan/First-Repo/main/nba.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32823 (32K) [text/plain]
# Saving to: ‘nba.csv’
#
# nba.csv             100%[===================>]  32.05K  --.-KB/s    in 0.001s
#
# 2023-12-04 08:03:40 (21.9 MB/s) - ‘nba.csv’ saved [32823/32823]

# %%
#Untuk menampilkan data nba
df = pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# <font color="blue"><center> **Jawaban A.1.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban A.2.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban A.3.** </center></font>

# %% [markdown]
# ## Soal B

# %% [markdown]
# Gunakanlah data dari /kaggle/input/diamonds/diamonds-3.csv
# dengan konten data sebagai berikut:
# ![Screenshot 2022-11-11 034644.png](data:image/png;base64,...)
#
#
# 1.   Group data diamond berdasarkan *cut*, aplikasikan aggregation dengan fungsi mean.
# 2.   Lakukan groupby pada data berdasarkan kriteria cut (kualitas) dan color (warna) secara berurutan, dengan aggregasi pada column carat, table, dan price saja, dengan fungsi agregasi mean. Berapa nilai dari carat diamond yang berkriteria very good dan berwarna H?
# 3.   Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan, kemudian aggregasi objek group by nya dengan fungsi rata2 dan median. Berapa nilai median dari harga diamond berkualitas good dan berwarna F?
# 4.   Lakukan groupby pada data berdasarkan kriteria cut(kualitas), kemudian aggreagate dengan fungsi max pada column price dan fungsi min pada column carat. Berapa nilai max dari price untuk diamond berkualitas Ideal?
# 5.   Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian lakukan aggregasi dengan fungsi standar deviasi pada column carat dan fungsi rentang nilai antara max dan min pada column price. Berapa selisih harga tertinggi dan terendah dari diamond berkualitas Premium?

# %%
#Untuk mengunduh data diamonds sehingga bisa diolah
# !wget https://raw.githubusercontent.com/ammarhan/First-Repo/main/diamonds.csv
# Out:
# --2023-12-04 08:03:47--  https://raw.githubusercontent.com/ammarhan/First-Repo/main/diamonds.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2772143 (2.6M) [text/plain]
# Saving to: ‘diamonds.csv’
#
# diamonds.csv        100%[===================>]   2.64M  --.-KB/s    in 0.01s
#
# 2023-12-04 08:03:47 (200 MB/s) - ‘diamonds.csv’ saved [2772143/2772143]

# %%
#Untuk menampilkan data diamonds
df = pd.read_csv('diamonds.csv')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# <font color="blue"><center> **Jawaban B.1.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban B.2.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban B.3.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban B.4.** </center></font>

# %% [markdown]
# <font color="blue"><center> **Jawaban B.5.** </center></font>
